# %% [markdown]
# # Welcome to RAG week!!
#
# ## Expert Knowledge Worker
#
# ### A question answering Assistant that is an expert knowledge worker
# ### To be used by employees of Insurellm, an Insurance Tech company
# ### The AI assistant needs to be accurate and the solution should be low cost.
#
# This project will use RAG (Retrieval Augmented Generation) to ensure our question/answering assistant has high accuracy.
#
# This first implementation will use a simplistic, brute-force type of RAG..

# %%
# %pip install gradio openai glob pathlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gradio in /Users/priyaraja/Library/Python/3.9/lib/python/site-packages (4.44.1)
# Requirement already satisfied: openai in /Users/priyaraja/Library/Python/3.9/lib/python/site-packages (2.7.2)
# ERROR: Could not find a version that satisfies the requirement glob (from versions: none)
# ERROR: No matching distribution found for glob
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import glob
from openai import OpenAI
from dotenv import load_dotenv
import gradio as gr
from pathlib import Path

# %%
# %pip install dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: dotenv in /Users/priyaraja/Library/Python/3.9/lib/python/site-packages (0.9.9)
# Requirement already satisfied: python-dotenv in /Users/priyaraja/Library/Python/3.9/lib/python/site-packages (from dotenv) (1.2.1)
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
if openai_api_key:
    print(f"OpenAI API key exist and begins {openai_api_key[:8]}")
else:
    print(f"OpenAI aPI key not present")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 load_dotenv(override=True)
#       2 openai_api_key = os.getenv('OPENAI_API_KEY')
#       3 if openai_api_key:
#
# NameError: name 'load_dotenv' is not defined
